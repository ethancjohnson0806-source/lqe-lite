# %% [markdown]
# # 09 — Quantum Error Correction
#
# This lesson is adapted for the pure-NumPy browser build. See the full LQE repository for unavailable modules.

# %%
from lqe import StabilizerSim
sim = StabilizerSim(5)
print("Browser-safe QEC demo: stabilizer backend initialized")
print("For full surface-code decoding, use the full LQE repository locally.")
